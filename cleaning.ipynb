# %%
# Import
import pandas as pd
import numpy as ny

# %%
# Connect to CSV
a = pd.read_csv("resources/Anime.csv")

# %%
# Look at the Data Frame
a.head()
# Out:
#       ID                             Title  \
# 0  16498                Shingeki no Kyojin
# 1   1535                        Death Note
# 2   5114  Fullmetal Alchemist: Brotherhood
# 3  30276                     One Punch Man
# 4  11757                  Sword Art Online
#
#                                             Synonyms  \
# 0                                           AoT, SnK
# 1                                                 DN
# 2  Hagane no Renkinjutsushi Fullmetal Alchemist, ...
# 3                  One Punch-Man, One-Punch Man, OPM
# 4                                         S.A.O, SAO
#
#                      Japanese                          English  \
# 0                       進撃の巨人                  Attack on Titan
# 1                       デスノート                       Death Note
# 2  鋼の錬金術師 FULLMETAL ALCHEMIST  Fullmetal Alchemist Brotherhood
# 3                      ワンパンマン                    One Punch Man
# ...

# %%
# Looking at the data types
a.dtypes
# Out:
# ID                    int64
# Title                object
# Synonyms             object
# Japanese             object
# English              object
# Synopsis             object
# Type                 object
# Episodes            float64
# Status               object
# Start_Aired          object
# End_Aired            object
# Premiered            object
# Broadcast            object
# Producers            object
# Licensors            object
# Studios              object
# Source               object
# Genres               object
# Themes               object
# Demographics         object
# Duration_Minutes    float64
# Rating               object
# Score               float64
# Scored_Users        float64
# Ranked              float64
# Popularity            int64
# Members               int64
# Favorites             int64
# dtype: object

# %%
# Checking Information
a.columns
# Out:
# Index(['ID', 'Title', 'Synonyms', 'Japanese', 'English', 'Synopsis', 'Type',
#        'Episodes', 'Status', 'Start_Aired', 'End_Aired', 'Premiered',
#        'Broadcast', 'Producers', 'Licensors', 'Studios', 'Source', 'Genres',
#        'Themes', 'Demographics', 'Duration_Minutes', 'Rating', 'Score',
#        'Scored_Users', 'Ranked', 'Popularity', 'Members', 'Favorites'],
#       dtype='object')

# %%
# Checking Information
a['Demographics'].unique()
# Out:
# array(['Shounen', 'Seinen', 'Unknown', 'Shoujo', 'Kids', 'Josei',
#        'Kids, Shounen', 'Josei, Shoujo', 'Kids, Seinen', 'Kids, Shoujo'],
#       dtype=object)

# %%
# Checking Information
a['Status'].unique()
# Out:
# array(['Finished Airing', 'Currently Airing', 'Not yet aired'],
#       dtype=object)

# %%
# Droping unneeded columns
a2 = a.drop(columns=
['Japanese', 
'Members', 
'Synopsis', 
'Synonyms', 
'Broadcast', 
'Producers'
]

)

# %%
a2.head()
# Out:
#       ID                             Title                          English  \
# 0  16498                Shingeki no Kyojin                  Attack on Titan
# 1   1535                        Death Note                       Death Note
# 2   5114  Fullmetal Alchemist: Brotherhood  Fullmetal Alchemist Brotherhood
# 3  30276                     One Punch Man                    One Punch Man
# 4  11757                  Sword Art Online                 Sword Art Online
#
#   Type  Episodes           Status  Start_Aired     End_Aired    Premiered  \
# 0   TV      25.0  Finished Airing  Apr 7, 2013  Sep 29, 2013  Spring 2013
# 1   TV      37.0  Finished Airing  Oct 4, 2006  Jun 27, 2007    Fall 2006
# 2   TV      64.0  Finished Airing  Apr 5, 2009   Jul 4, 2010  Spring 2009
# 3   TV      12.0  Finished Airing  Oct 5, 2015  Dec 21, 2015    Fall 2015
# 4   TV      25.0  Finished Airing  Jul 8, 2012  Dec 23, 2012  Summer 2012
#
# ...

# %%
a2.isna().sum()
# Out:
# ID                     0
# Title                  0
# English                0
# Type                   0
# Episodes             547
# Status                 0
# Start_Aired            0
# End_Aired              0
# Premiered              0
# Licensors              0
# Studios                0
# Source                 0
# Genres                 0
# Themes                 0
# Demographics           0
# Duration_Minutes     599
# Rating                 0
# Score               6898
# Scored_Users        6898
# Ranked              1924
# Popularity             0
# Favorites              0
# dtype: int64

# %%
a2.loc[a2.loc[:, "Episodes"].isna(), :]
# Out:
#           ID                                              Title  \
# 24        21                                          One Piece
# 194    34566                    Boruto: Naruto Next Generations
# 362    44511                                       Chainsaw Man
# 626      235                                    Detective Conan
# 813    50172                                 Mob Psycho 100 III
# ...      ...                                                ...
# 21056  51287                                           Emo Faze
# 21151  51390                                 Ying Yu Siwan Nian
# 21164  51207                                Jiuzhou Piaomiao Lu
# 21204  53085  Akuyaku Reijou nanode Last Boss wo Kattemimash...
# 21281  53020                               Kikenshingou Goddess
#
#                               English Type  Episodes            Status  \
# 24                          One Piece   TV       NaN  Currently Airing
# ...

# %%
a2.drop(
    a2[a2['Status'] == "Not yet aired"
    ].index, inplace=True
    )

# %%
a2.drop(
    a2[a2['Status'] == "Currently Airing"
    ].index, inplace=True
    )

# %%
a2['Status'].unique()
# Out:
# array(['Finished Airing'], dtype=object)

# %%
a2.isna().sum()
# Out:
# ID                     0
# Title                  0
# English                0
# Type                   0
# Episodes               7
# Status                 0
# Start_Aired            0
# End_Aired              0
# Premiered              0
# Licensors              0
# Studios                0
# Source                 0
# Genres                 0
# Themes                 0
# Demographics           0
# Duration_Minutes     171
# Rating                 0
# Score               6284
# Scored_Users        6284
# Ranked              1456
# Popularity             0
# Favorites              0
# dtype: int64

# %%
a2.loc[a2.loc[:, "Episodes"].isna(), :]
# Out:
#           ID                    Title             English     Type  Episodes  \
# 16167  37024  Momoya Norihei Anime CM             Unknown  Special       NaN
# 16802  24775  Koishite!! Namashi-chan             Unknown       TV       NaN
# 16863  32237            Burutabu-chan             Unknown       TV       NaN
# 17473  30129        Konna Ko Iru kana             Unknown       TV       NaN
# 19438  48221       Bobble Bobble Cook  Bobble Bobble Cook       TV       NaN
# 19781  48322              Jouiseon-in   Warriors in Black       TV       NaN
# 20179  48258          Super Talk Talk     Super Talk Talk       TV       NaN
#
#                 Status  Start_Aired      End_Aired    Premiered Licensors  \
# 16167  Finished Airing         1958           2012      Unknown   Unknown
# 16802  Finished Airing  Jan 3, 2015        Unknown      Unknown   Unknown
# 16863  Finished Airing      Unknown  Not Available      Unknown   Unknown
# ...

# %%
a2 = a2.dropna(subset=['Episodes'])

# %%
a2.isna().sum()
# Out:
# ID                     0
# Title                  0
# English                0
# Type                   0
# Episodes               0
# Status                 0
# Start_Aired            0
# End_Aired              0
# Premiered              0
# Licensors              0
# Studios                0
# Source                 0
# Genres                 0
# Themes                 0
# Demographics           0
# Duration_Minutes     171
# Rating                 0
# Score               6277
# Scored_Users        6277
# Ranked              1456
# Popularity             0
# Favorites              0
# dtype: int64

# %%
a2.loc[a2.loc[:, "Duration_Minutes"].isna(), :]
# Out:
#           ID                                           Title  \
# 4054   48830        Free! Movie 5: The Final Stroke - Kouhen
# 4445   35267      Shingeki no Kyojin-ten 360° Taikan Theater
# 8038   37169                                Sakkai Eightraid
# 8927   36952               Tennis no Ouji-sama: Best Games!!
# 9190   31244  Makura no Danshi: Sono Ato no Makura no Danshi
# ...      ...                                             ...
# 20483  52029               Video Ehon Nippon Mukashibahanshi
# 20531  44294                         Gangtie Feilong (Movie)
# 20538  48193                            Mabeobsonyeo Dee Dee
# 20710  48192                             Longlong Juggessji?
# 20719  44739                      Qi Tian Da Sheng Qianchuan
#
#                                                  English     Type  Episodes  \
# 4054                                             Unknown    Movie       1.0
# 4445   Attack on Titan Exhibition 360-degree Experien...  Special       3.0
# ...

# %%
a2 = a2.dropna(subset=['Duration_Minutes'])

# %%
a2.isna().sum()
# Out:
# ID                     0
# Title                  0
# English                0
# Type                   0
# Episodes               0
# Status                 0
# Start_Aired            0
# End_Aired              0
# Premiered              0
# Licensors              0
# Studios                0
# Source                 0
# Genres                 0
# Themes                 0
# Demographics           0
# Duration_Minutes       0
# Rating                 0
# Score               6119
# Scored_Users        6119
# Ranked              1456
# Popularity             0
# Favorites              0
# dtype: int64

# %%
a2.loc[a2.loc[:, "Scored_Users"].isna(), :]
# Out:
#           ID                                              Title  \
# 3445   50593             Natsu e no Tunnel, Sayonara no Deguchi
# 4810   43556                   Tsurune Movie: Hajimari no Issha
# 4911   49283                                    Bakuten!! Movie
# 5516   48624                        Re:cycle of the Penguindrum
# 5777   40722  Deemo Movie: Sakura no Oto - Anata no Kanadeta...
# ...      ...                                                ...
# 21455  45064           Xiao Gongzhu Ai Wei La Yu Shenmi Wangguo
# 21456  45065         Xiao Gongzhu Ai Wei La Yu Shenmi Wangguo 2
# 21457  45059                            Yongzhe Chuang Mo Cheng
# 21458  45063                    Yu Shen Chuan: Wangzhe Shaonian
# 21459  45061                                      Konglong Wang
#
#                                 English   Type  Episodes           Status  \
# 3445                            Unknown  Movie       1.0  Finished Airing
# ...

# %%
a2 = a2.dropna(subset=['Scored_Users', 'Score'])

# %%
a2.isna().sum()
# Out:
# ID                     0
# Title                  0
# English                0
# Type                   0
# Episodes               0
# Status                 0
# Start_Aired            0
# End_Aired              0
# Premiered              0
# Licensors              0
# Studios                0
# Source                 0
# Genres                 0
# Themes                 0
# Demographics           0
# Duration_Minutes       0
# Rating                 0
# Score                  0
# Scored_Users           0
# Ranked              1436
# Popularity             0
# Favorites              0
# dtype: int64

# %%
a2.loc[a2.loc[:, "Ranked"].isna(), :]
# Out:
#           ID                                              Title   English  \
# 1182    1639                                       Boku no Pico   Unknown
# 1556   40746                                           Overflow  Overflow
# 1875   37585                                  Yarichin☆Bitch-bu   Unknown
# 2129   10851                                           Euphoria   Unknown
# 2277    5391                                      Pico to Chico   Unknown
# ...      ...                                                ...       ...
# 13843  17825                Ikenai Boy: Ikasu Maruhi Hand Power   Unknown
# 13947  51338                                       Kisaku Reiwa   Unknown
# 14076  29111  Onna Spy Goumon: Teki no Ajito wa Jotai Goumonsho   Unknown
# 14394  43016                                  Words Worth Omake   Unknown
# 14983  49752                             Kaihouku: Chikan Harem   Unknown
#
#           Type  Episodes           Status   Start_Aired      End_Aired  \
# ...

# %%
a2 = a2.dropna(subset=['Ranked'])

# %%
a2.isna().sum()
# Out:
# ID                  0
# Title               0
# English             0
# Type                0
# Episodes            0
# Status              0
# Start_Aired         0
# End_Aired           0
# Premiered           0
# Licensors           0
# Studios             0
# Source              0
# Genres              0
# Themes              0
# Demographics        0
# Duration_Minutes    0
# Rating              0
# Score               0
# Scored_Users        0
# Ranked              0
# Popularity          0
# Favorites           0
# dtype: int64

# %%
a2.to_excel('resources/anime_clean.xlsx')
