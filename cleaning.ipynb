# %%
# Import
import pandas as pd
import numpy as ny

# %%
# Connect to CSV
a = pd.read_csv("resources/Anime.csv")

# %%
# Look at the Data Frame
a.head()
# Out:
#       ID                             Title  \
# 0  16498                Shingeki no Kyojin
# 1   1535                        Death Note
# 2   5114  Fullmetal Alchemist: Brotherhood
# 3  30276                     One Punch Man
# 4  11757                  Sword Art Online
#
#                                             Synonyms  \
# 0                                           AoT, SnK
# 1                                                 DN
# 2  Hagane no Renkinjutsushi Fullmetal Alchemist, ...
# 3                  One Punch-Man, One-Punch Man, OPM
# 4                                         S.A.O, SAO
#
#                      Japanese                          English  \
# 0                       進撃の巨人                  Attack on Titan
# 1                       デスノート                       Death Note
# 2  鋼の錬金術師 FULLMETAL ALCHEMIST  Fullmetal Alchemist Brotherhood
# 3                      ワンパンマン                    One Punch Man
# 4                ソードアート・オンライン                 Sword Art Online
#
#                                             Synopsis Type  Episodes  \
# 0  Centuries ago, mankind was slaughtered to near...   TV      25.0
# 1  Brutal murders, petty thefts, and senseless vi...   TV      37.0
# 2  After a horrific alchemy experiment goes wrong...   TV      64.0
# 3  The seemingly unimpressive Saitama has a rathe...   TV      12.0
# 4  Ever since the release of the innovative Nerve...   TV      25.0
#
#             Status  Start_Aired  ...                    Themes Demographics  \
# 0  Finished Airing  Apr 7, 2013  ...  Gore, Military, Survival      Shounen
# 1  Finished Airing  Oct 4, 2006  ...             Psychological      Shounen
# 2  Finished Airing  Apr 5, 2009  ...                  Military      Shounen
# 3  Finished Airing  Oct 5, 2015  ...       Parody, Super Power       Seinen
# 4  Finished Airing  Jul 8, 2012  ...  Love Polygon, Video Game      Unknown
#
#   Duration_Minutes                          Rating  Score Scored_Users  \
# 0             24.0  R - 17+ (violence & profanity)  8.531     519803.0
# 1             23.0  R - 17+ (violence & profanity)  8.621     485487.0
# 2             24.0  R - 17+ (violence & profanity)  9.131     900398.0
# 3             24.0  R - 17+ (violence & profanity)  8.511      19066.0
# 4             23.0       PG-13 - Teens 13 or older  7.201     990254.0
#
#     Ranked Popularity  Members Favorites
# 0   1002.0          1  3524109    155695
# 1    732.0          2  3504535    159701
# 2     12.0          3  2978455    207772
# 3   1112.0          4  2879907     59651
# 4  29562.0          5  2813565     64997
#
# [5 rows x 28 columns]

# %%
# Looking at the data types
a.dtypes
# Out:
# ID                    int64
# Title                object
# Synonyms             object
# Japanese             object
# English              object
# Synopsis             object
# Type                 object
# Episodes            float64
# Status               object
# Start_Aired          object
# End_Aired            object
# Premiered            object
# Broadcast            object
# Producers            object
# Licensors            object
# Studios              object
# Source               object
# Genres               object
# Themes               object
# Demographics         object
# Duration_Minutes    float64
# Rating               object
# Score               float64
# Scored_Users        float64
# Ranked              float64
# Popularity            int64
# Members               int64
# Favorites             int64
# dtype: object

# %%
# Checking Information
a.columns
# Out:
# Index(['ID', 'Title', 'Synonyms', 'Japanese', 'English', 'Synopsis', 'Type',
#        'Episodes', 'Status', 'Start_Aired', 'End_Aired', 'Premiered',
#        'Broadcast', 'Producers', 'Licensors', 'Studios', 'Source', 'Genres',
#        'Themes', 'Demographics', 'Duration_Minutes', 'Rating', 'Score',
#        'Scored_Users', 'Ranked', 'Popularity', 'Members', 'Favorites'],
#       dtype='object')

# %%
# Checking Information
a['Demographics'].unique()
# Out:
# array(['Shounen', 'Seinen', 'Unknown', 'Shoujo', 'Kids', 'Josei',
#        'Kids, Shounen', 'Josei, Shoujo', 'Kids, Seinen', 'Kids, Shoujo'],
#       dtype=object)

# %%
# Checking Information
a['Status'].unique()
# Out:
# array(['Finished Airing', 'Currently Airing', 'Not yet aired'],
#       dtype=object)

# %%
# Droping unneeded columns
a2 = a.drop(columns=
['Japanese', 
'Members', 
'Synopsis', 
'Synonyms', 
'Broadcast', 
'Producers',
'Scored_Users',
'Ranked',
'Themes',
"Rating",
"Duration_Minutes",
"Licensors",
"Title",
"ID"
]

)

# %%
a2.head()
# Out:
#                            English Type  Episodes           Status  \
# 0                  Attack on Titan   TV      25.0  Finished Airing
# 1                       Death Note   TV      37.0  Finished Airing
# 2  Fullmetal Alchemist Brotherhood   TV      64.0  Finished Airing
# 3                    One Punch Man   TV      12.0  Finished Airing
# 4                 Sword Art Online   TV      25.0  Finished Airing
#
#    Start_Aired     End_Aired    Premiered       Studios       Source  \
# 0  Apr 7, 2013  Sep 29, 2013  Spring 2013    Wit Studio        Manga
# 1  Oct 4, 2006  Jun 27, 2007    Fall 2006      Madhouse        Manga
# 2  Apr 5, 2009   Jul 4, 2010  Spring 2009         Bones        Manga
# 3  Oct 5, 2015  Dec 21, 2015    Fall 2015      Madhouse    Web manga
# 4  Jul 8, 2012  Dec 23, 2012  Summer 2012  A-1 Pictures  Light novel
#
#                                 Genres Demographics  Score  Popularity  \
# 0                        Action, Drama      Shounen  8.531           1
# 1               Supernatural, Suspense      Shounen  8.621           2
# 2    Action, Adventure, Drama, Fantasy      Shounen  9.131           3
# 3                       Action, Comedy       Seinen  8.511           4
# 4  Action, Adventure, Fantasy, Romance      Unknown  7.201           5
#
#    Favorites
# 0     155695
# 1     159701
# 2     207772
# 3      59651
# 4      64997

# %%
a2.isna().sum()
# Out:
# English            0
# Type               0
# Episodes         547
# Status             0
# Start_Aired        0
# End_Aired          0
# Premiered          0
# Studios            0
# Source             0
# Genres             0
# Demographics       0
# Score           6898
# Popularity         0
# Favorites          0
# dtype: int64

# %%
a2.loc[a2.loc[:, "Episodes"].isna(), :]
# Out:
#                               English Type  Episodes            Status  \
# 24                          One Piece   TV       NaN  Currently Airing
# 194    Boruto Naruto Next Generations   TV       NaN  Currently Airing
# 362                      Chainsaw Man   TV       NaN     Not yet aired
# 626                       Case Closed   TV       NaN  Currently Airing
# 813                Mob Psycho 100 III   TV       NaN     Not yet aired
# ...                               ...  ...       ...               ...
# 21056                    Law of Devil  ONA       NaN     Not yet aired
# 21151                         Unknown  ONA       NaN     Not yet aired
# 21164                         Unknown  ONA       NaN     Not yet aired
# 21204                         Unknown  ONA       NaN  Currently Airing
# 21281                         Unknown  ONA       NaN  Currently Airing
#
#         Start_Aired End_Aired    Premiered            Studios       Source  \
# 24     Oct 20, 1999   Unknown    Fall 1999     Toei Animation        Manga
# 194     Apr 5, 2017   Unknown  Spring 2017            Pierrot        Manga
# 362    Oct 12, 2022   Unknown    Fall 2022              MAPPA        Manga
# 626     Jan 8, 1996   Unknown  Winter 1996  TMS Entertainment        Manga
# 813     Oct 6, 2022   Unknown    Fall 2022              Bones    Web manga
# ...             ...       ...          ...                ...          ...
# 21056          2022   Unknown      Unknown            Unknown    Web novel
# 21151          2022   Unknown      Unknown            Unknown        Other
# 21164          2022   Unknown      Unknown            Unknown        Other
# 21204  Sep 17, 2022   Unknown      Unknown          AQUA ARIS  Light novel
# 21281  Feb 21, 2019   Unknown      Unknown              Angle     Original
#
#                              Genres Demographics  Score  Popularity  Favorites
# 24       Action, Adventure, Fantasy      Shounen  8.671          25     177620
# 194      Action, Adventure, Fantasy      Shounen  5.781         195       6687
# 362               Action, Adventure      Shounen    NaN         364      14181
# 626      Adventure, Comedy, Mystery      Shounen  8.161         627      13059
# 813    Action, Comedy, Supernatural      Unknown    NaN         814       2785
# ...                             ...          ...    ...         ...        ...
# 21056    Action, Adventure, Fantasy      Unknown    NaN       21085          0
# 21151       Action, Fantasy, Sci-Fi      Unknown    NaN       21181          0
# 21164        Action, Drama, Fantasy      Unknown    NaN       21195          0
# 21204               Comedy, Fantasy       Shoujo    NaN       21237          0
# 21281                        Comedy      Unknown    NaN       21313          0
#
# [547 rows x 14 columns]

# %%
a2.drop(
    a2[a2['Status'] == "Not yet aired"
    ].index, inplace=True
    )

# %%
a2.drop(
    a2[a2['Status'] == "Currently Airing"
    ].index, inplace=True
    )

# %%
a2['Status'].unique()
# Out:
# array(['Finished Airing'], dtype=object)

# %%
a2.isna().sum()
# Out:
# English            0
# Type               0
# Episodes           7
# Status             0
# Start_Aired        0
# End_Aired          0
# Premiered          0
# Studios            0
# Source             0
# Genres             0
# Demographics       0
# Score           6284
# Popularity         0
# Favorites          0
# dtype: int64

# %%
a2.loc[a2.loc[:, "Episodes"].isna(), :]
# Out:
#                   English     Type  Episodes           Status  Start_Aired  \
# 16167             Unknown  Special       NaN  Finished Airing         1958
# 16802             Unknown       TV       NaN  Finished Airing  Jan 3, 2015
# 16863             Unknown       TV       NaN  Finished Airing      Unknown
# 17473             Unknown       TV       NaN  Finished Airing     Apr 1986
# 19438  Bobble Bobble Cook       TV       NaN  Finished Airing     Mar 2010
# 19781   Warriors in Black       TV       NaN  Finished Airing         2008
# 20179     Super Talk Talk       TV       NaN  Finished Airing      Unknown
#
#            End_Aired    Premiered           Studios    Source  \
# 16167           2012      Unknown           Unknown  Original
# 16802        Unknown      Unknown  Kachidoki Studio  Original
# 16863  Not Available      Unknown           Unknown  Original
# 17473       Mar 1991  Spring 1986           Unknown   Unknown
# 19438       Oct 2012  Spring 2010           Unknown  Original
# 19781        Unknown      Unknown           Unknown  Original
# 20179  Not Available      Unknown           Unknown  Original
#
#                 Genres Demographics  Score  Popularity  Favorites
# 16167           Comedy      Unknown    NaN       16192          0
# 16802    Slice of Life         Kids    NaN       16827          0
# 16863  Comedy, Fantasy      Unknown    NaN       16887          0
# 17473          Unknown         Kids    NaN       17497          0
# 19438          Unknown         Kids    NaN       19465          0
# 19781  Action, Fantasy         Kids    NaN       19809          0
# 20179           Comedy         Kids    NaN       20207          0

# %%
a2 = a2.dropna(subset=['Episodes'])

# %%
a2.isna().sum()
# Out:
# English            0
# Type               0
# Episodes           0
# Status             0
# Start_Aired        0
# End_Aired          0
# Premiered          0
# Studios            0
# Source             0
# Genres             0
# Demographics       0
# Score           6277
# Popularity         0
# Favorites          0
# dtype: int64

# %%
a2.isna().sum()
# Out:
# English            0
# Type               0
# Episodes           0
# Status             0
# Start_Aired        0
# End_Aired          0
# Premiered          0
# Studios            0
# Source             0
# Genres             0
# Demographics       0
# Score           6277
# Popularity         0
# Favorites          0
# dtype: int64

# %%
a2.loc[a2.loc[:, "Score"].isna(), :]
# Out:
#                                 English   Type  Episodes           Status  \
# 3445                            Unknown  Movie       1.0  Finished Airing
# 4810                            Unknown  Movie       1.0  Finished Airing
# 4911                   Backflip!! Movie  Movie       1.0  Finished Airing
# 5516                            Unknown  Movie       2.0  Finished Airing
# 5777                Deemo Memorial Keys  Movie       1.0  Finished Airing
# ...                                 ...    ...       ...              ...
# 21455          Princess and the Kingdom  Movie       1.0  Finished Airing
# 21456  Avera and the Mystical Kingdom 2  Movie       1.0  Finished Airing
# 21457                        Brave City  Movie       1.0  Finished Airing
# 21458           The Juvenile of King Yu  Movie       1.0  Finished Airing
# 21459                         Dino King  Movie       1.0  Finished Airing
#
#         Start_Aired      End_Aired Premiered                    Studios  \
# 3445    Sep 9, 2022  Not Available   Unknown                       CLAP
# 4810   Aug 19, 2022  Not Available   Unknown            Kyoto Animation
# 4911    Jul 2, 2022  Not Available   Unknown                      Zexcs
# 5516   Apr 29, 2022   Jul 22, 2022   Unknown  Brain's Base, Lapin Track
# 5777   Feb 25, 2022  Not Available   Unknown  Production I.G, Signal.MD
# ...             ...            ...       ...                        ...
# 21455  May 12, 2018  Not Available   Unknown                    Unknown
# 21456  Aug 22, 2020  Not Available   Unknown                    Unknown
# 21457  Mar 16, 2018  Not Available   Unknown                    Unknown
# 21458  Aug 15, 2018  Not Available   Unknown                    Unknown
# 21459  Nov 10, 2018  Not Available   Unknown                    Unknown
#
#             Source                               Genres Demographics  Score  \
# 3445   Light novel               Drama, Mystery, Sci-Fi      Unknown    NaN
# 4810   Light novel                               Sports      Unknown    NaN
# 4911      Original                               Sports      Unknown    NaN
# 5516      Original  Avant Garde, Comedy, Drama, Mystery      Unknown    NaN
# 5777          Game                       Drama, Fantasy      Unknown    NaN
# ...            ...                                  ...          ...    ...
# 21455      Unknown                   Adventure, Fantasy         Kids    NaN
# 21456      Unknown                   Adventure, Fantasy         Kids    NaN
# 21457     Original           Adventure, Comedy, Fantasy      Unknown    NaN
# 21458     Original                   Adventure, Fantasy      Unknown    NaN
# 21459     Original                            Adventure         Kids    NaN
#
#        Popularity  Favorites
# 3445         3447        300
# 4810         4815         49
# 4911         4916        108
# 5516         5521         30
# 5777         5782         34
# ...           ...        ...
# 21455       21487          0
# 21456       21488          0
# 21457       21489          0
# 21458       21490          0
# 21459       21490          0
#
# [6277 rows x 14 columns]

# %%
a2 = a2.dropna(subset=['Score'])

# %%
a2.isna().sum()
# Out:
# English         0
# Type            0
# Episodes        0
# Status          0
# Start_Aired     0
# End_Aired       0
# Premiered       0
# Studios         0
# Source          0
# Genres          0
# Demographics    0
# Score           0
# Popularity      0
# Favorites       0
# dtype: int64

# %%
a2.isnull().sum()
# Out:
# English         0
# Type            0
# Episodes        0
# Status          0
# Start_Aired     0
# End_Aired       0
# Premiered       0
# Studios         0
# Source          0
# Genres          0
# Demographics    0
# Score           0
# Popularity      0
# Favorites       0
# dtype: int64

# %%
a2.head()
# Out:
#                            English Type  Episodes           Status  \
# 0                  Attack on Titan   TV      25.0  Finished Airing
# 1                       Death Note   TV      37.0  Finished Airing
# 2  Fullmetal Alchemist Brotherhood   TV      64.0  Finished Airing
# 3                    One Punch Man   TV      12.0  Finished Airing
# 4                 Sword Art Online   TV      25.0  Finished Airing
#
#    Start_Aired     End_Aired    Premiered       Studios       Source  \
# 0  Apr 7, 2013  Sep 29, 2013  Spring 2013    Wit Studio        Manga
# 1  Oct 4, 2006  Jun 27, 2007    Fall 2006      Madhouse        Manga
# 2  Apr 5, 2009   Jul 4, 2010  Spring 2009         Bones        Manga
# 3  Oct 5, 2015  Dec 21, 2015    Fall 2015      Madhouse    Web manga
# 4  Jul 8, 2012  Dec 23, 2012  Summer 2012  A-1 Pictures  Light novel
#
#                                 Genres Demographics  Score  Popularity  \
# 0                        Action, Drama      Shounen  8.531           1
# 1               Supernatural, Suspense      Shounen  8.621           2
# 2    Action, Adventure, Drama, Fantasy      Shounen  9.131           3
# 3                       Action, Comedy       Seinen  8.511           4
# 4  Action, Adventure, Fantasy, Romance      Unknown  7.201           5
#
#    Favorites
# 0     155695
# 1     159701
# 2     207772
# 3      59651
# 4      64997

# %%
a2.dtypes
# Out:
# English          object
# Type             object
# Episodes        float64
# Status           object
# Start_Aired      object
# End_Aired        object
# Premiered        object
# Studios          object
# Source           object
# Genres           object
# Demographics     object
# Score           float64
# Popularity        int64
# Favorites         int64
# dtype: object

# %%
a2.to_csv('resources/anime_clean.csv')
